# %% [markdown]
# <a href="https://colab.research.google.com/github/moriahobaje/Neural_Networking/blob/main/dog_breed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/moriahobaje/Neural_Networking.git
# Out:
# Cloning into 'Neural_Networking'...
# remote: Enumerating objects: 20498, done.
# remote: Total 20498 (delta 0), reused 0 (delta 0), pack-reused 20498
# Receiving objects: 100% (20498/20498), 684.99 MiB | 41.84 MiB/s, done.
# Checking out files: 100% (20582/20582), done.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
